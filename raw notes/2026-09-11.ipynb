# %% [markdown]
# Fundamental Therorem of algebra: Every non-zero, single-variable, degree n polynomial with complex coefficients has, counted with multiplicity, exactly n complex roots.

# %% [markdown]
# wilkinson's polynomial :
#
#
# w(x) = sum from k=0 to 20 of a_k * x^k
#
# that is, multiplying (x-1)(x-2) up to (x-20)
#
# > note on this

# %% [markdown]
# > understand plots here https://cu-numcomp.github.io/fall26/slides/2026-09-11-polynomials/#wilkinsons-polynomial
#
# the plots should show the problem is ill-conditioned

# %% [markdown]
# plots show extreme sensitivity when posed using the `fromroots` package - small pertebations in a_k from Wilkonson's create huge changes in roots

# %% [markdown]
# which is better to model inputs to a rootfinder? the Pi def of polynomials or the sigma def of polynomials?
#
# if you have the pi def, you don't need a rootfinding algo because the roots are just right there in the equation.

# %% [markdown]
# posits are an alternative to floating points, which gives better accuracy for values near 1.
