# %% [markdown]
# We spent a lot of time talking about the backward stability concepts covered in my note for the previous lecture

# %% [markdown]
# Accuracy of backward stable algorithms
#
# Backward stable algorithms have relative error less than or equal to K (the condition number of the function) times machine epsilon. Backward stability is generally the best we can hope for.
#
# In practice, it is rarely possible for a function to be backward stable when the output space is higher dimensional than the input space.
